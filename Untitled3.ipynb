# %% [markdown]
# <a href="https://colab.research.google.com/github/Earanna038/Earanna038/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
stocks=pd.Series(np.random.randn(1000))

# %%
stocks
# Out:
# 0      0.655027
# 1     -1.862892
# 2     -0.397620
# 3      0.713423
# 4      0.418588
#          ...
# 995   -0.197321
# 996    0.322306
# 997   -0.575848
# 998   -0.975290
# 999    0.269978
# Length: 1000, dtype: float64

# %%
stocks.index=range(1000,2000,1)

# %%
stocks
# Out:
# 1000    0.655027
# 1001   -1.862892
# 1002   -0.397620
# 1003    0.713423
# 1004    0.418588
#           ...
# 1995   -0.197321
# 1996    0.322306
# 1997   -0.575848
# 1998   -0.975290
# 1999    0.269978
# Length: 1000, dtype: float64

# %%
stocks.plot()

# %%
stocks.cumsum().plot()

# %%
stocks=pd.DataFrame(np.random.rand(1000,4))

# %%
stocks.cumsum().plot()

# %%
stocks.index=pd.date_range('01/01/2020',periods=1000)
stocks.columns=['India','Pakistan','Bangaladesh','afganisthan']

# %%
stocks.cumsum().plot()

# %%
stocks.to_excel('stocks.xlsx')
